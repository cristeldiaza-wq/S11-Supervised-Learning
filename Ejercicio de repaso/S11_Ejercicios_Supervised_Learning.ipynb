# %% [markdown]
# # 🧠 S11 - Ejercicios de Supervised Learning
#
# ## 🎯 Objetivo
# Practicar los conceptos vistos en el módulo:
# - Encoding de variables categóricas
# - Transformaciones de variables numéricas
# - Manejo de datos desbalanceados
# - Creación de Pipelines con `ColumnTransformer`
#
# Dataset principal: **Titanic (Seaborn)**
# Incluye un ejercicio bonus con el dataset **Tips**.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report
)

# %% [markdown]
# ## 🚢 Carga del Dataset Titanic

# %%
df = sns.load_dataset("titanic")
df = df[["survived", "pclass", "sex", "age", "fare", "embarked"]]
df = df.dropna()
df.head()

# %% [markdown]
# ## 🔹 Ejercicio 1: Exploración de Datos

# %%
# Escribe tu código aquí

# %% [markdown]
# ## 🔹 Ejercicio 2: One-Hot Encoding

# %%
# Aplica OneHotEncoder a 'sex' y 'embarked'

# %% [markdown]
# ## 🔹 Ejercicio 3: Ordinal Encoding

# %%
# Aplica OrdinalEncoder a 'pclass'

# %% [markdown]
# ## 🔹 Ejercicio 4: Escalamiento de Variables

# %%
# Aplica StandardScaler y MinMaxScaler a 'age' y 'fare'

# %% [markdown]
# ## 🔹 Ejercicio 5: División de los Datos

# %%
# Divide el dataset en entrenamiento y prueba

# %% [markdown]
# ## 🔹 Ejercicio 6: Regresión Logística Base

# %%
# Entrena un modelo de regresión logística

# %% [markdown]
# ## 🔹 Ejercicio 7: Evaluación del Modelo

# %%
# Calcula accuracy, precision, recall y F1-score

# %% [markdown]
# ## 🔹 Ejercicio 8: Manejo de Datos Desbalanceados

# %%
# Usa class_weight='balanced' y compara resultados

# %% [markdown]
# ## 🔹 Ejercicio 9: ColumnTransformer

# %%
# Crea un ColumnTransformer para variables numéricas y categóricas

# %% [markdown]
# ## 🔹 Ejercicio 10: Pipeline

# %%
# Construye un Pipeline con el preprocesador y LogisticRegression

# %% [markdown]
# ## 🔹 Ejercicio 11: Evaluación del Pipeline

# %%
# Entrena y evalúa el pipeline

# %% [markdown]
# ## 🔹 Ejercicio 12: Nombres de las Columnas Transformadas

# %%
# Obtén los nombres de las características transformadas

# %% [markdown]
# ## 🌟 Ejercicio Bonus: Dataset Tips

# %%
tips = sns.load_dataset("tips")
tips.head()

# %%
# Predice la propina utilizando regresión lineal
